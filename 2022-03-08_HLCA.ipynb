# %%
import scanpy as sc
sc.set_figure_params(dpi=100, frameon=False, color_map='Reds')

# %%
# %%time
adata = sc.read('/storage/groups/ml01/workspace/hlca_lisa.sikkema_malte.luecken/HLCA_for_internal_sharing.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 584884 × 28527
# ...

# %%
sc.pl.umap(adata, color='ann_level_1')

# %%
adata = adata[adata.obs.ann_level_1 == 'Epithelial']

# %%
sc.pl.umap(adata, color='anatomical_region_level_1')

# %%
sc.pl.umap(adata, color=['ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5'], ncols=1)

# %%
sc.pl.umap(adata, color='study')
